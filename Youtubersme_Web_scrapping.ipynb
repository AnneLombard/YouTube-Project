# %% [markdown]
# Scrapping du site : https://us.youtubers.me/mrbeast/youtube-estimated-earnings

# %%
import requests
from bs4 import BeautifulSoup

url = "https://us.youtubers.me/vlad-and-nikita/youtube-estimated-earnings"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
date = soup.find_all("tr")
date
# Out:
# [<tr><th>Month</th><th>Estimated earnings</th></tr>,
#  <tr><td>November 2024</td><td>$ 1.32M</td></tr>,
#  <tr><td>October 2024</td><td>$ 1.13M</td></tr>,
#  <tr><td>September 2024</td><td>$ 1.23M</td></tr>,
#  <tr><td>August 2024</td><td>$ 1.38M</td></tr>,
#  <tr><td>July 2024</td><td>$ 1.03M</td></tr>,
#  <tr><td>June 2024</td><td>$ 1.41M</td></tr>,
#  <tr><td>May 2024</td><td>$ 1.06M</td></tr>,
#  <tr><td>April 2024</td><td>$ 1.7M</td></tr>,
#  <tr><td>March 2024</td><td>$ 1.66M</td></tr>,
#  <tr><td>February 2024</td><td>$ 2.16M</td></tr>,
#  <tr><td>January 2024</td><td>$ 993K</td></tr>,
#  <tr><td>December 2023</td><td>$ 1.16M</td></tr>,
#  <tr><td>November 2023</td><td>$ 1.22M</td></tr>,
#  <tr><td>October 2023</td><td>$ 1.63M</td></tr>,
#  <tr><td>July 2023</td><td>$ 511K</td></tr>,
#  <tr><td>June 2023</td><td>$ 874K</td></tr>,
#  <tr><td>May 2023</td><td>$ 668K</td></tr>,
#  <tr><td>April 2023</td><td>$ 696K</td></tr>,
#  <tr><td>March 2023</td><td>$ 1.17M</td></tr>,
#  <tr><td>February 2023</td><td>$ 1.04M</td></tr>,
#  <tr><td>January 2023</td><td>$ 683K</td></tr>,
#  <tr><td>December 2022</td><td>$ 764K</td></tr>]

# %%
date[1].text.split("$ ")
# Out:
# ['November 2024', '1.32M']

# %%
data = {"date":[],"estimation_earning":[]}

for i in date[1:]:
    print(i.text.split("$ "))
    data["date"].append(i.text.split("$ ")[0])
    data["estimation_earning"].append(i.text.split("$ ")[1])
# Out:
# ['November 2024', '1.32M']
# ['October 2024', '1.13M']
# ['September 2024', '1.23M']
# ['August 2024', '1.38M']
# ['July 2024', '1.03M']
# ['June 2024', '1.41M']
# ['May 2024', '1.06M']
# ['April 2024', '1.7M']
# ['March 2024', '1.66M']
# ['February 2024', '2.16M']
# ['January 2024', '993K']
# ['December 2023', '1.16M']
# ['November 2023', '1.22M']
# ['October 2023', '1.63M']
# ['July 2023', '511K']
# ['June 2023', '874K']
# ['May 2023', '668K']
# ['April 2023', '696K']
# ['March 2023', '1.17M']
# ['February 2023', '1.04M']
# ['January 2023', '683K']
# ['December 2022', '764K']

# %%
import pandas as pd
df = pd.DataFrame(data)

def parse_earnings(value):
    if value.endswith('K'):  # Si la valeur se termine par 'K', convertir en milliers
        return float(value[:-1]) * 1_000
    elif value.endswith('M'):  # Si la valeur se termine par 'M', convertir en millions
        return float(value[:-1]) * 1_000_000
    return float(value)  # Sinon, convertir directement

df["estimation_earning_numeric"] = df["estimation_earning"].apply(parse_earnings)
df["date"] = pd.to_datetime(df["date"], format='%B %Y')
df
# Out:
#          date estimation_earning  estimation_earning_numeric
# 0  2024-11-01              1.32M                   1320000.0
# 1  2024-10-01              1.13M                   1130000.0
# 2  2024-09-01              1.23M                   1230000.0
# 3  2024-08-01              1.38M                   1380000.0
# 4  2024-07-01              1.03M                   1030000.0
# 5  2024-06-01              1.41M                   1410000.0
# 6  2024-05-01              1.06M                   1060000.0
# 7  2024-04-01               1.7M                   1700000.0
# 8  2024-03-01              1.66M                   1660000.0
# 9  2024-02-01              2.16M                   2160000.0
# 10 2024-01-01               993K                    993000.0
# 11 2023-12-01              1.16M                   1160000.0
# 12 2023-11-01              1.22M                   1220000.0
# 13 2023-10-01              1.63M                   1630000.0
# 14 2023-07-01               511K                    511000.0
# 15 2023-06-01               874K                    874000.0
# 16 2023-05-01               668K                    668000.0
# 17 2023-04-01               696K                    696000.0
# 18 2023-03-01              1.17M                   1170000.0
# 19 2023-02-01              1.04M                   1040000.0
# 20 2023-01-01               683K                    683000.0
# 21 2022-12-01               764K                    764000.0

# %%
# Exporter le DataFrame dans un fichier CSV
df.to_csv("Vlad_and_Niki.csv", index=False)  # index=False pour exclure l'index du DataFrame dans le fichier CSV

# %%
import plotly.express as plt
import pandas as pd

plt.bar(x=df["date"],y=df["estimation_earning_numeric"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b4d75e65-9678-4ba2-a84f-0506d87a667a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4d75e65-9678-4ba2-a84f-0506d87a667a")) {                    Plotly.newPlot(                        "b4d75e65-9678-4ba2-a84f-0506d87a667a",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2024-11-01T00:00:00","2024-10-01T00:00:00","2024-09-01T00:00:00","2024-08-01T00:00:00","2024-07-01T00:00:00","2024-06-01T00:00:00","2024-05-01T00:00:00","2024-04-01T00:00:00","2024-03-01T00:00:00","2024-02-01T00:00:00","2024-01-01T00:00:00","2023-12-01T00:00:00","2023-11-01T00:00:00","2023-10-01T00:00:00","2023-07-01T00:00:00","2023-06-01T00:00:00","2023-05-01T00:00:00","2023-04-01T00:00:00","2023-03-01T00:00:00","2023-02-01T00:00:00","2023-01-01T00:00:00","2022-12-01T00:00:00"],"xaxis":"x","y":[1320000.0,1130000.0,1230000.0,1380000.0,1030000.0,1410000.0,1060000.0,1700000.0,1660000.0,2160000.0,993000.0,1160000.0,1220000.0,1630000.0,511000.0,874000.0,668000.0,696000.0,1170000.0,1040000.0,683000.0,764000.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"] ...
